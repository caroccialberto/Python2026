# %% [markdown]
# <a href="https://colab.research.google.com/github/caroccialberto/Python2026/blob/main/0603_in_class_exercise_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://www.bvspiemonte.it/wp-content/uploads/2019/03/logo-ISS.jpg" width="180">
# </p>
#
# # Hands-on Exercises
#
# This repository contains the hands-on exercises for the course **Python for Scientific Programming**.
#
# All material is available at the following GitHub repository:
# https://github.com/pumazzo/ISS-Python2026
#
# Please make sure you have access to the repository before starting the session.
#
# ---
#
# ## Working Modality
#
# - Exercises can be solved **in pairs**.
# - **One person types**, the other reviews and reasons about the solution.
# - **Alternate at the keyboard** regularly to ensure both participants actively code and reflect on the solutions.
#
# Ask the tutor for help if you need
#
# ---
#
# ## Google Colab: Disable Automatic Completion
#
# To avoid over-reliance on suggestions and to improve learning outcomes, **automatic code completion must be disabled** in Google Colab.
#
# Follow these steps:
#
# 1. Open your notebook in **Google Colab**.
# 2. Click on **Tools → Settings**.
# 3. Select the **Editor** tab.
# 4. Disable:
#    - **Enable code completion**
#    - **Automatically trigger code completion**
# 5. Close the settings panel.
#
# Proceed with the exercises only after completing this step.

# %% [markdown]
# # Beginner Python Exercise Notebook
#
# This notebook is organized as a sequence of short recaps and guided exercises.
#
# Rules for use:
# - Read the recap for a topic.
# - Try each exercise in order.
# - Use the hint only when needed.
# - Write your code in the provided starter cells.
#
# The notebook is executable as-is: every code cell already contains valid Python code or comments.

# %%
# General notebook setup
# Run this cell first.

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (6, 4)

# %% [markdown]
# ### Easy Exercise 1
#
# **Problem:** Create a dictionary called `student` with the keys `name`, `grade`, and `passed`.
# Use an `if/else` statement to print `"Passed"` if `passed` is `True`, otherwise print `"Not passed"`.
#
# **Hint:** Access dictionary values with square brackets, for example `student["name"]`.

# %%
# Write your code here

student = {"name":"alberto","grade":17,"passed":False}

if student["passed"] == True:
  print("Passed")
else:
  print("Not passed")
# Out:
# Not passed

# %%
student.keys()
# Out:
# dict_keys(['name', 'grade', 'passed'])

# %% [markdown]
# ### Intermediate Exercise
#
# **Problem:** You are given a list of dictionaries, where each dictionary describes a product with:
# - `name`,
# - `price`,
# - `quantity`.
#
# Write a function called `inventory_summary(products)` that:
# 1. loops through the products,
# 2. computes the total value `price * quantity` for each product,
# 3. keeps only products with `quantity > 0`,
# 4. returns a new dictionary where:
#    - each key is the product name,
#    - each value is the total value for that product.
#
# Then print the resulting dictionary.
#
# **Hint:** Combine a loop, an `if` condition, and a function that builds a new dictionary.

# %%
# Write your code here

products = [
    {"name": "pen", "price": 1.5, "quantity": 10},
    {"name": "notebook", "price": 4.0, "quantity": 3},
    {"name": "eraser", "price": 0.8, "quantity": 0},
]

def inventory_summary(products):
    summary = {}
    for d in products:    # loop over products
      if d["quantity"] > 0:  # keep only products with quantity > 0
        summary[list(d.values())[0]] = math.prod(list(d.values())[1:]) # compute total value = price * quantity
    # store the result in summary
    return summary

result = inventory_summary(products)
print(result)
# Out:
# {'pen': 15.0, 'notebook': 12.0}

# %%
math.prod(list(products[0].values())[1:])
# Out:
# 15.0

# %% [markdown]
# ## NumPy — Recap
#
# NumPy is a library for numerical computing in Python. Its main object is the array.
# Arrays make it easy to perform fast arithmetic, compute statistics such as sum and mean, and inspect shape and dimensions.
# Indexing works similarly to lists, but arrays are more powerful for numerical operations.

# %%
# Section setup for NumPy
import numpy as np

# %% [markdown]
# ### Easy Exercise 1
#
# **Problem:** Import NumPy as `np`, create a 1D array with the values `[2, 4, 6, 8, 10]`, and print it.
#
# **Hint:** Use `np.array(...)`.

# %%
# Write your code here

import numpy as np
arr = np.array([2, 4, 6, 8, 10])
print(arr)
a = np.arange(2,11,2)
# Out:
# [ 2  4  6  8 10]
# '[ 2  4  6  8 10]'

# %% [markdown]
# ### Easy Exercise 2
#
# **Problem:** Create a 2D NumPy array with shape `(2, 3)`.
# Print:
# - the full array,
# - the element in the first row and second column,
# - the shape of the array.
#
# **Hint:** Array indices start at 0, so the first row and second column is `[0, 1]`.

# %%
# Write your code here

arr = np.arange(1,7)
arr = arr.reshape(2,3)

print(arr)
print(arr[0, 1])
print(arr.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
# (2, 3)

# %% [markdown]
# ### Easy Exercise 3
#
# **Problem:** Create two NumPy arrays of the same length.
# Compute:
# - their element-wise sum,
# - their element-wise product,
# - the mean of the first array,
# - the sum of the second array.
#
# **Hint:** NumPy supports direct arithmetic such as `a + b` and `a * b`.

# %%
# Write your code here

a = np.array([1, 2, 3, 4])
b = np.array([10, 20, 30, 40])

print(a + b)
print(a * b)

print(np.mean(a))
print(np.sum(a))
# Out:
# [11 22 33 44]
# [ 10  40  90 160]
# 2.5
# 10

# %% [markdown]
# ### Intermediate Exercise
#
# **Problem:** Use NumPy and Matplotlib to plot one or more circumferences.
#
# You are given:
# - a list of centers, for example `[(0, 0), (3, 2)]`,
# - a list of radii, for example `[1.0, 2.0]`.
#
# For each pair `(center, radius)`:
# 1. generate many angles between `0` and `2*pi`,
# 2. compute the circumference points with trigonometric functions,
# 3. plot the points with `plt.scatter(...)`,
# 4. keep the aspect ratio equal so circles look like circles.
#
# **Hint:** Use:
# - `np.linspace(...)` for the angles,
# - `np.cos(...)` and `np.sin(...)` for coordinates,
# - `x = cx + r * np.cos(theta)`,
# - `y = cy + r * np.sin(theta)`.

# %%
# Write your code here

import numpy as np
import matplotlib.pyplot as plt

centers = [(0, 0), (3, 2)]
radii = [1.0, 2.0]

n = 1000

theta = np.linspace(0,2*np.pi, n)
for (cx, cy), r in zip(centers, radii):
     x = cx + r * np.cos(theta)
     y = cy + r * np.sin(theta)
     plt.scatter(x, y, s=10, label=f"center=({cx}, {cy}), r={r}")

plt.gca().set_aspect("equal")
plt.title("Circumference points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
#plt.axis("equal")
plt.show()

# %% [markdown]
# ## Matplotlib — Recap
#
# Matplotlib is a common Python library for plotting. The `matplotlib.pyplot` module is usually imported as `plt`.
# You can create line plots and scatter plots from synthetic or real data, then improve readability with labels, titles, legends, and a grid.

# %%
# Section setup for Matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Easy Exercise 1
#
# **Problem:** Generate `x` values from 0 to 10 and compute `y = 2 * x + 1`.
# Create a line plot of `y` versus `x`.
#
# **Hint:** You can use `np.arange(...)` or `np.linspace(...)`.

# %%
# Write your code here

import numpy as np
import matplotlib.pyplot as plt


x = np.arange(11)
y = 2 * x + 1

plt.plot(x, y, color = "orange", label = "y = a*x+b")
plt.xlabel("x")
plt.legend()
# plt.plot(x, y, label="y = 2x + 1")
# plt.xlabel("x")
# plt.ylabel("y")
plt.title("Simple line plot")
# plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# [link text](https://)### Easy Exercise 2
#
# **Problem:** Create two curves on the same figure:
# - `y1 = x`
# - `y2 = x**2`
#
# Add axis labels, a title, a legend, and a grid.
#
# **Hint:** Call `plt.plot(...)` twice before `plt.show()`.

# %%
# Write your code here

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(20)
y1 = x
y2 = x**2
y3 = x**3
y4 = x**0.5
plt.plot(x, y1, label = "y = x", alpha = 0.25)
plt.plot(x, y2, label = "y = x^2")
plt.plot(x, y3, label = "y = x^3")
plt.plot(x, y4, label = "y = sqrt(x)")
# plt.plot(x, y1, label="y = x")
# plt.plot(x, y2, label="y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Two curves")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Pandas — Recap
#
# Pandas is used to work with tabular data. A `DataFrame` stores rows and columns, similar to a spreadsheet.
# You can add columns, remove duplicate rows, detect missing values, and replace missing numeric values with the mean of a column.

# %%
# Section setup for Pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Easy Exercise 1
#
# **Problem:** Create a DataFrame with two columns:
# - `name`
# - `score`
#
# Use at least four rows, then print the DataFrame.
#
# **Hint:** Pass a dictionary of lists to `pd.DataFrame(...)`.

# %%
# Write your code here

import pandas as pd

d = {"name":["alb","rob","g","vi"], "score": np.random.randint(0,30,4) }
df = pd.DataFrame(d)
print(df)
# Out:
#   name  score
# 0  alb      7
# 1  rob      4
# 2    g     24
# 3   vi     22

# %%
d = {"name":["alb","rob",], "score": np.random.randint(0,30,4) }

# %% [markdown]
# ### Easy Exercise 3
#
# **Problem:** Create a DataFrame that contains:
# - at least one duplicated row,
# - at least one missing numeric value.
#
# Then:
# 1. detect missing values,
# 2. remove duplicates,
# 3. print the cleaned DataFrame.
#
# **Hint:** Useful methods:
# - `df.isna()`
# - `df.drop_duplicates()`

# %%
#Write your code here

import pandas as pd
import numpy as np

df = pd.DataFrame({
    "name": ["A", "B", "B", "C"],
    "value": [1.0, np.nan, np.nan, 4.0]
})

df.isna()
df_clean = df.drop_duplicates()
df_clean = df_clean.dropna()
df_clean
# Out:
#   name  value
# 0    A    1.0
# 3    C    4.0

# %% [markdown]
# ### Intermediate Exercise
#
# **Problem:** Download a small public dataset from a direct URL, load it with Pandas, and visualize it with Matplotlib.
#
# Use this dataset URL:
#
# `https://vega.github.io/vega-lite/data/seattle-weather.csv`
#
# Tasks:
# 1. load the dataset into a DataFrame,
# 2. convert the `date` column to datetime,
# 3. compute the average `temp_max` for each weather category,
# 4. create a bar plot of the averages.
#
# **Hint:** Useful tools:
# - `pd.read_csv(url)`
# - `pd.to_datetime(...)`
# - `groupby(...).mean()`
# - `plot(kind="bar")` or `plt.bar(...)`

# %%
# Write your code here

import pandas as pd
import matplotlib.pyplot as plt

url = "https://vega.github.io/vega-lite/data/seattle-weather.csv"

df = pd.read_csv(url)
df["date"] = pd.to_datetime(df["date"])


print(df.head())

summary = df.groupby(["weather"])["temp_max"].mean()

print(summary)
summary.plot(kind = "bar")
plt.show()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain
# weather
# drizzle    15.926415
# fog        16.757426
# rain       13.454602
# snow        5.573077
# sun        19.861875
# Name: temp_max, dtype: float64

# %%
# Write your code here

import pandas as pd
import matplotlib.pyplot as plt

url = "https://vega.github.io/vega-lite/data/seattle-weather.csv"

df = pd.read_csv(url)
df["date"] = pd.to_datetime(df["date"])

df = pd.read_csv(url)
print(df.head())

df["date"] = pd.to_datetime(df["date"])
#summary =  use group by (weather) and then select temp_max

#summary.plot(kind="bar")
#plt.xlabel("Weather category")
#plt.ylabel("Average max temperature")
#plt.title("Average maximum temperature by weather type")
#plt.grid(True)
#plt.show()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# ### Intermediate Exercise
#
# **Problem:** Create or load a small dataset about students with columns such as:
# - `student`,
# - `hours_studied`,
# - `score`.
#
# Make sure the dataset contains:
# - at least one duplicate row,
# - at least one missing numeric value.
#
# Then:
# 1. remove duplicates,
# 2. impute missing numeric values with the mean of the column,
# 3. visualize the cleaned data with Matplotlib using a scatter plot of `hours_studied` versus `score`.
#
# **Hint:** You can combine:
# - `drop_duplicates()`
# - `fillna(df[column].mean())`
# - `plt.scatter(...)`

# %%
# Write your code here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "student": ["Alice", "Bob", "Bob", "Cara", "David"],
    "hours_studied": [2.0, 4.0, 4.0, np.nan, 5.0],
    "score": [65.0, 80.0, 80.0, 75.0, np.nan]
})

cleaned_df = df.copy().drop_duplicates()
cleaned_df["hours_studied"] = df["hours_studied"].fillna(df["hours_studied"].mean())
cleaned_df["score"] = df["score"].fillna(df["score"].mean())

plt.scatter(cleaned_df["hours_studied"], cleaned_df["score"])
plt.xlabel("Hours studied")
plt.ylabel("Score")
plt.title("Cleaned student data")
plt.grid(True)
plt.show()
print(df)
print(cleaned_df)
# Out:
#   student  hours_studied  score
# 0   Alice            2.0   65.0
# 1     Bob            4.0   80.0
# 2     Bob            4.0   80.0
# 3    Cara            NaN   75.0
# 4   David            5.0    NaN
#   student  hours_studied  score
# 0   Alice           2.00   65.0
# 1     Bob           4.00   80.0
# 3    Cara           3.75   75.0
# 4   David           5.00   75.0
